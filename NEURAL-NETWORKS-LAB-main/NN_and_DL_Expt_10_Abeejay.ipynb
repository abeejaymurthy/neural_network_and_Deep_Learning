# %% [markdown]
# <a href="https://colab.research.google.com/github/SRET-College/Sem-6-NN-and-DL/blob/main/NN_and_DL_Expt_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================
# 1. IMPORT LIBRARIES
# ============================================
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.sequence import pad_sequences


# ============================================
# 2. LOAD DATASET (IMDB)
# ============================================
vocab_size = 10000

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=vocab_size)

print("Training samples:", len(x_train))
print("Testing samples:", len(x_test))


# ============================================
# 3. PREPROCESSING
# ============================================
max_len = 200

x_train = pad_sequences(x_train, maxlen=max_len, padding='post')
x_test  = pad_sequences(x_test,  maxlen=max_len, padding='post')


# ============================================
# 4. BUILD RNN MODEL (FIXED)
# ============================================
model = models.Sequential([

    #  Input layer (fixes unbuilt issue)
    layers.Input(shape=(max_len,)),

    # Embedding layer
    layers.Embedding(input_dim=vocab_size, output_dim=128),

    #  Simple RNN layer
    layers.SimpleRNN(64),

    # Dense layer
    layers.Dense(64, activation='relu'),

    # Dropout
    layers.Dropout(0.5),

    # Output layer
    layers.Dense(1, activation='sigmoid')
])

# Now summary will show correct parameters
model.summary()


# ============================================
# 5. COMPILE MODEL
# ============================================
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)


# ============================================
# 6. TRAIN MODEL
# ============================================
history = model.fit(
    x_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)


# ============================================
# 7. EVALUATE MODEL
# ============================================
loss, accuracy = model.evaluate(x_test, y_test)

print("\nTest Accuracy:", accuracy * 100)


# ============================================
# 8. PREDICT NEW TEXT
# ============================================
word_index = tf.keras.datasets.imdb.get_word_index()

def encode_text(text):
    words = text.lower().split()
    encoded = [word_index.get(word, 2) for word in words]
    padded = pad_sequences([encoded], maxlen=max_len, padding='post')
    return padded


def predict_sentiment(text):
    processed = encode_text(text)
    prediction = model.predict(processed)[0][0]

    print("\nReview:", text)

    if prediction >= 0.5:
        print("Sentiment: Positive 😊")
    else:
        print("Sentiment: Negative 😞")


# Example predictions
predict_sentiment("This movie was excellent and amazing")
predict_sentiment("This movie was very bad and boring")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Training samples: 25000
# Testing samples: 25000
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 200, 128)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,296,577 (4.95 MB)
#  Trainable params: 1,296,577 (4.95 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.5088 - loss: 0.6983 - val_accuracy: 0.5174 - val_loss: 0.6911
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.5203 - loss: 0.6928 - val_accuracy: 0.5476 - val_loss: 0.6820
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.5888 - loss: 0.6469 - val_accuracy: 0.5974 - val_loss: 0.6296
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6451 - loss: 0.5682 - val_accuracy: 0.6190 - val_loss: 0.6190
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.6244 - loss: 0.5846 - val_accuracy: 0.5732 - val_loss: 0.6666
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.6622 - loss: 0.5327 - val_accuracy: 0.6014 - val_loss: 0.6557
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.6792 - loss: 0.4841 - val_accuracy: 0.5986 - val_loss: 0.6978
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6949 - loss: 0.4569 - val_accuracy: 0.6056 - val_loss: 0.7267
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - accuracy: 0.7027 - loss: 0.4494 - val_accuracy: 0.5992 - val_loss: 0.7887
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.7046 - loss: 0.4278 - val_accuracy: 0.6020 - val_loss: 0.8668
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.7125 - loss: 0.4170 - val_accuracy: 0.5974 - val_loss: 0.8946
# Epoch 12/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7124 - loss: 0.4169 - val_accuracy: 0.5622 - val_loss: 0.8540
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.6942 - loss: 0.4614 - val_accuracy: 0.6092 - val_loss: 0.8998
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7176 - loss: 0.4112 - val_accuracy: 0.5866 - val_loss: 0.8891
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0